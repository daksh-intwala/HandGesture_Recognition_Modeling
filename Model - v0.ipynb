# %%
from google.colab import files
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = '/content/drive/MyDrive/Capstone/Datasets/2/data.csv'

# %%
df = pd.read_csv(folder_path)
df.head(5)
# Out:
#         0        1    2        3        4    5        6        7        8  \
# 0  0.3451  0.83893 -0.0  0.68423  0.84153  0.0  0.37431  0.85629 -0.00252
# 1  0.0000  0.00000  0.0  0.00000  0.00000  0.0  0.00000  0.00000  0.00000
# 2  0.0000  0.00000  0.0  0.00000  0.00000  0.0  0.00000  0.00000  0.00000
# 3  0.0000  0.00000  0.0  0.00000  0.00000  0.0  0.00000  0.00000  0.00000
# 4  0.0000  0.00000  0.0  0.00000  0.00000  0.0  0.00000  0.00000  0.00000
#
#          9  ...      117      118      119      120      121     122      123  \
# 0  0.64808  ...  0.69283  0.93758 -0.00312  0.32659  0.92407 -0.0076  0.69564
# 1  0.00000  ...  0.00000  0.00000  0.00000  0.00000  0.00000  0.0000  0.00000
# 2  0.00000  ...  0.00000  0.00000  0.00000  0.00000  0.00000  0.0000  0.00000
# 3  0.00000  ...  0.00000  0.00000  0.00000  0.00000  0.00000  0.0000  0.00000
# 4  0.00000  ...  0.00000  0.00000  0.00000  0.00000  0.00000  0.0000  0.00000
#
#        124      125  label
# ...

# %%
v = []
t=[]
#v = np.array(v)

# %%
for row in range(len(df)-1):
  for column in range(len(df.columns)-1):
    t.append(df.iloc[row,column])
  v.append([t])
  t=[]
print(v)
      #np.append(v,df.iloc[[row,column]])
# Out:
# [[[0.3451, 0.83893, -0.0, 0.68423, 0.84153, 0.0, 0.37431, 0.85629, -0.00252, 0.64808, 0.86128, -0.00379, 0.38552, 0.90268, -0.006, 0.63352, 0.90521, -0.00574, 0.38259, 0.94329, -0.009, 0.6339, 0.94543, -0.00644, 0.37655, 0.9714, -0.01019, 0.63829, 0.97355, -0.00558, 0.38219, 0.91042, -0.01303, 0.65436, 0.91461, -0.01559, 0.38362, 0.96659, -0.02179, 0.64792, 0.97247, -0.02355, 0.38077, 0.95369, -0.02455, 0.64453, 0.95592, -0.02623, 0.37998, 0.93518, -0.0241, 0.6464, 0.93338, -0.02543, 0.35856, 0.91391, -0.01538, 0.67801, 0.91794, -0.01422, 0.3621, 0.96643, -0.02171, 0.66857, 0.97142, -0.01685, 0.36114, 0.95377, -0.02084, 0.66228, 0.95766, -0.01506, 0.36012, 0.93546, -0.01867, 0.6635, 0.93837, -0.01368, 0.33718, 0.91423, -0.01758, 0.69639, 0.91783, -0.01244, 0.34304, 0.95864, -0.02079, 0.68442, 0.95771, -0.01198, 0.34388, 0.94733, -0.01468, 0.67931, 0.94448, -0.00592, 0.34336, 0.93009, -0.00978, 0.6812, 0.93001, -0.00259, 0.31934, 0.91333, -0.01995, 0.70965, 0.91612, -0.01094, 0.32844,
# ...

# %%
path = '/content/drive/MyDrive/Capstone/Datasets/2/data.csv'

# %%
from numpy import genfromtxt
my_data = genfromtxt(path, delimiter=',')

# %%
my_data.shape
# Out:
# (126, 127)

# %%
a =[]

# %%
df = pd.read_csv(path)
a = np.array(df.drop('label',axis=1))

# %%
print(a)
# Out:
# [[ 3.45100000e-01  8.38930000e-01 -0.00000000e+00 ...  6.95640000e-01
#    9.26280000e-01  9.60000000e-04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [ 3.60350000e-01  8.26110000e-01  0.00000000e+00 ...  5.96730000e-01
#    9.34790000e-01 -4.46600000e-02]
#  [ 3.73632520e-01  8.96438360e-01  2.00965744e-07 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]

# %%
a=np.array(a).T
print(a)
# Out:
# [[ 3.45100000e-01  0.00000000e+00  0.00000000e+00 ...  3.60350000e-01
#    3.73632520e-01  0.00000000e+00]
#  [ 8.38930000e-01  0.00000000e+00  0.00000000e+00 ...  8.26110000e-01
#    8.96438360e-01  0.00000000e+00]
#  [-0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    2.00965744e-07  0.00000000e+00]
#  ...
#  [ 6.95640000e-01  0.00000000e+00  0.00000000e+00 ...  5.96730000e-01
#    0.00000000e+00  0.00000000e+00]
#  [ 9.26280000e-01  0.00000000e+00  0.00000000e+00 ...  9.34790000e-01
#    0.00000000e+00  0.00000000e+00]
#  [ 9.60000000e-04  0.00000000e+00  0.00000000e+00 ... -4.46600000e-02
#    0.00000000e+00  0.00000000e+00]]

# %%
actions = np.array(['2','3'])

# %%
import os

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(126,1)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=True, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:Layer lstm_39 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_40 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_41 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
y_train = []
for i in range(125):
  y_train.append(2)
y_train=np.array(y_train)

# %%
a.shape
# Out:
# (126, 125)

# %%
p=a.reshape((a.shape[1], a.shape[0],1))

# %%
p = np.array(v)
p.shape
# Out:
# (124, 1, 126)

# %%
model.fit(p, y_train, epochs=2000)
